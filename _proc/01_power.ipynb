# %% [raw]
# ---
# description: Power analysis for simple AB experiments
# output-file: power.html
# title: Power
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(simulate_power_binary)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/power.py#L44){target="_blank" style="float:right; font-size:smaller"}
#
# ### simulate_power_binary
#
# >      simulate_power_binary (sizes=array([ 10000,  20000,  30000,  40000,
# >                             50000,  60000,  70000,  80000,         90000,
# >                             100000]), cr0=0.01, cr1=0.012, realizations=1000,
# >                             alpha=0.05, one_sided=True, power=0.8)
#
# Simulates the power using two test: Bayesian testing (Probability B>A) and fisher test (p-value).
# Return total sample size (e.g. we need to devide by 2 for each variant sample size given 50/50 split)

# %%
#| echo: false
#| output: asis
show_doc(sample_size_binary)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/power.py#L134){target="_blank" style="float:right; font-size:smaller"}
#
# ### sample_size_binary
#
# >      sample_size_binary (cr0=0.01, cr1=0.012, alpha=0.05, power=0.8,
# >                          one_sided=True)
#
# Calculates the sample size for chi2 using sns package

# %%
#| echo: false
#| output: asis
show_doc(simulate_power_continuous)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/power.py#L150){target="_blank" style="float:right; font-size:smaller"}
#
# ### simulate_power_continuous
#
# >      simulate_power_continuous (sizes=array([ 1000,  3000,  5000,  7000,
# >                                 9000, 11000, 13000, 15000, 17000,
# >                                 19000]), effect=0.05, realizations=1000,
# >                                 alpha=0.05, one_sided=True, power=0.8)
#
# Simulates the power using t-test and bayesian testing (only one-sided)
# Return total sample size (e.g. we need to devide by 2 for each variant sample size given 50/50 split)

# %%
# https://www.stat.ubc.ca/~rollin/stats/ssize/n2.html

# %%
#| echo: false
#| output: asis
show_doc(sample_size_continuous)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/power.py#L220){target="_blank" style="float:right; font-size:smaller"}
#
# ### sample_size_continuous
#
# >      sample_size_continuous (mu1=5.0, mu2=5.05, sigma=1, alpha=0.05,
# >                              power=0.8, one_sided=True)
#
# forumla: https://towardsdatascience.com/required-sample-size-for-a-b-testing-6f6608dd330a
# web calulator: https://www.stat.ubc.ca/~rollin/stats/ssize/n2.html
# returns sample size per variant
# two-sided test
