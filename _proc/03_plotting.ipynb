# %% [raw]
# ---
# description: Methods to visualize data.
# output-file: plotting.html
# title: Plotting
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(plot_distribution)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/plotting.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_distribution
#
# >      plot_distribution (df, show_rug=True)
#
# Plots the distribution for both groups of generate_continuous_data

# %%
#| echo: false
#| output: asis
show_doc(plot_power)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/plotting.py#L43){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_power
#
# >      plot_power (simulation, added_lines=[], is_effect=True)
#
# Takes simulation dict and plots the power over sample sizes
# Added lines: plot horizontal lines for additional sample size estimations, takes a list of dicts with sample_size=sample_size,label=label
# is_effect: True: there is an effect in reality, hence we are interested in power. False: we are interested in false positives.

# %%
#| echo: false
#| output: asis
show_doc(plot_betas)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/plotting.py#L119){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_betas
#
# >      plot_betas (df_contingency, xmin=0.0, xmax=0.2, names=['A', 'B'])
#
# Plots two beta distributions, one for control and for variant.
# Takes as input a contigency table as dataframe

# %%
#| echo: false
#| output: asis
show_doc(plot_binary_power)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/plotting.py#L158){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_binary_power
#
# >      plot_binary_power (cr0=0.01, cr1=0.012, alpha=0.05, one_sided=True,
# >                         vline_power=0.8, powers=array([0.1 , 0.11, 0.12, 0.13,
# >                         0.14, 0.15, 0.16, 0.17, 0.18, 0.19, 0.2 ,        0.21,
# >                         0.22, 0.23, 0.24, 0.25, 0.26, 0.27, 0.28, 0.29, 0.3 ,
# >                         0.31,        0.32, 0.33, 0.34, 0.35, 0.36, 0.37, 0.38,
# >                         0.39, 0.4 , 0.41, 0.42,        0.43, 0.44, 0.45, 0.46,
# >                         0.47, 0.48, 0.49, 0.5 , 0.51, 0.52, 0.53,        0.54,
# >                         0.55, 0.56, 0.57, 0.58, 0.59, 0.6 , 0.61, 0.62, 0.63,
# >                         0.64,        0.65, 0.66, 0.67, 0.68, 0.69, 0.7 , 0.71,
# ...

# %%
#| echo: false
#| output: asis
show_doc(plot_continuous_power)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/plotting.py#L212){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_continuous_power
#
# >      plot_continuous_power (mu1=5.0, mu2=5.05, sigma=1, alpha=0.05,
# >                             one_sided=True, vline_power=0.8)
