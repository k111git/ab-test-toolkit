# %% [raw]
# ---
# description: Methods to analyse experiments once they are completed.
# output-file: analyze.html
# title: Analysis of experiments
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(p_value_binary)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/analyze.py#L13){target="_blank" style="float:right; font-size:smaller"}
#
# ### p_value_binary
#
# >      p_value_binary (df_contingency, one_sided=True)

# %%
#| echo: false
#| output: asis
show_doc(p_value_binary_from_counts)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/analyze.py#L25){target="_blank" style="float:right; font-size:smaller"}
#
# ### p_value_binary_from_counts
#
# >      p_value_binary_from_counts (n0, c0, n1, c1, one_sided=True)
#
# Return the p value for conversion rate experiment. Inputs:
# n0: Users control group
# c0: Converted users control group
# n1: Users treatment group
# c1: Converted users treatment group
