# %% [raw]
# ---
# description: Methods to generate synthetic datasets for binary and continuous experiments.
# output-file: data_generation.html
# title: Data Generation
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(generate_binary_data)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/generator.py#L19){target="_blank" style="float:right; font-size:smaller"}
#
# ### generate_binary_data
#
# >      generate_binary_data (N=1000, cr0=0.01, cr1=0.011, split=0.5)
#
# Generates synthethic data for a binary experiement with two groups (0: Control, 1: Variant).
# Inputs:
# N: Sample size (total number of users)
# Split: % of users assigned randomly to the variant (group 1)
# cr0: Conversion rate control
# cr1: Conversion rate variant

# %%
#| echo: false
#| output: asis
show_doc(generate_continuous_data)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/generator.py#L40){target="_blank" style="float:right; font-size:smaller"}
#
# ### generate_continuous_data
#
# >      generate_continuous_data (N=1000, base=5, effect=0, noise=1, std=1,
# >                                split=0.5)
#
# Generates synthethic data for a continuous experiement with two groups (0: Control, 1: Variant).
# Inputs:
# N: Sample size (total number of users)

# %%
#| echo: false
#| output: asis
show_doc(data_to_contingency)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/generator.py#L56){target="_blank" style="float:right; font-size:smaller"}
#
# ### data_to_contingency
#
# >      data_to_contingency (df)
#
# Converts output from generate_binary_data to a contingency table

# %%
#| echo: false
#| output: asis
show_doc(generate_contingency)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/generator.py#L68){target="_blank" style="float:right; font-size:smaller"}
#
# ### generate_contingency
#
# >      generate_contingency (N=1000, split=0.5, cr0=0.01, cr1=0.011,
# >                            exact=False)
#
# Generate contingency table using binominal distribution
# For exact=False, we draw the numbers from the binominal distribution.
# For exact=True, we calculate the numbers from multiplying number users * conversion rate

# %%
#| echo: false
#| output: asis
show_doc(contingency_from_counts)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/generator.py#L100){target="_blank" style="float:right; font-size:smaller"}
#
# ### contingency_from_counts
#
# >      contingency_from_counts (n0, c0, n1, c1)
#
# Generate contingency table from following input:
# n0: users in control group
# c0: number of converted users in control group
# n1: users in treatment group
# c1: number of converted user sin treatment group
