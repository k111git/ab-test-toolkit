# %% [raw]
# ---
# description: Wrappers to create showcases and function to explain concepts on a high
#   level.
# output-file: wrappers.html
# title: Wrappers
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(simulate_evolution_binary)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L27){target="_blank" style="float:right; font-size:smaller"}
#
# ### simulate_evolution_binary
#
# >      simulate_evolution_binary (N=10000, cr0=0.1, cr1=0.11,
# >                                 snapshot_sizes=array([ 1000,  2000,  3000,
# >                                 4000,  5000,  6000,  7000,  8000,  9000,
# >                                 10000]), one_sided=True)
#
# Simulates the evolution of a binary experiment.

# %%
#| echo: false
#| output: asis
show_doc(realizations_of_evolution_binary)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L66){target="_blank" style="float:right; font-size:smaller"}
#
# ### realizations_of_evolution_binary
#
# >      realizations_of_evolution_binary (N_realizations=50, cr0=0.1, cr1=0.11,
# >                                        snapshot_sizes=array([ 1000,  2000,
# >                                        3000,  4000,  5000,  6000,  7000,
# >                                        8000,  9000,        10000]),
# >                                        one_sided=True)

# %%
#| echo: false
#| output: asis
show_doc(plot_realization)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L108){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_realization
#
# >      plot_realization (plot_df, multiply_ate=1.0, alpha=0.05, ate_line=0.01,
# >                        info=False)

# %%
#| echo: false
#| output: asis
show_doc(plot_snapshots_distribution)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L226){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_snapshots_distribution
#
# >      plot_snapshots_distribution (snapshots, vline_x=None,
# >                                   snapshot_indices=None)

# %%
#| echo: false
#| output: asis
show_doc(analytics_null_vs_effect)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L253){target="_blank" style="float:right; font-size:smaller"}
#
# ### analytics_null_vs_effect
#
# >      analytics_null_vs_effect (r0, r1, alpha=0.1, ate_limit=0.005)
#
# Shows the power and false positives of using a p value vs directly the ATE
# r0,r1: Realization objects from realizations_of_evolution_binary
# r0: No effect
# r1: With effect

# %%
#| echo: false
#| output: asis
show_doc(plot_analytics)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L304){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_analytics
#
# >      plot_analytics (analytics)
#
# plots elements of confusion matrix over time

# %%
#| echo: false
#| output: asis
show_doc(plot_analytics_compact)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L421){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_analytics_compact
#
# >      plot_analytics_compact (analytics, approach)
#
# plots elements of confusion matrix over time.
# input: analytics element from analytics_null_vs_effect
# approach: "both", "ate", or "pv".

# %%
#| echo: false
#| output: asis
show_doc(plot_comparison_ate_pvalue)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L512){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_comparison_ate_pvalue
#
# >      plot_comparison_ate_pvalue (cr0=0.1, crmax=0.12, sizes=[1000, 2000, 5000,
# >                                  10000], one_sided=True)
#
# Compares the average treatment effect (difference in conversion rates) with the P value for different sample sizes.
# Inputs:
# sizes: List of total sample sizes considered
# cr0: baseline conversion rate
# crmax: max conversion rate (we will plot ATEs until crmax - cr0)
# Output: Plot

# %%
#| echo: false
#| output: asis
show_doc(hello)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L588){target="_blank" style="float:right; font-size:smaller"}
#
# ### hello
#
# >      hello ()

# %%
hello()
# Out:
#     Welcome :)
#
#     You can find additional documentation here: https://k111git.github.io/ab-test-toolkit/
