# %% [raw]
# ---
# description: Wrappers to create showcases. Wip.
# output-file: wrappers.html
# title: Wrappers
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(hello)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### hello
#
# >      hello ()

# %%
hello()
# Out:
#     Welcome :)
#
#     You can find additional documentation here: https://k111git.github.io/ab-test-simulator/
