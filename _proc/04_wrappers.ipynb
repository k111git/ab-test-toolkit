# %% [raw]
# ---
# description: Wrappers to create showcases and function to explain concepts on a high
#   level.
# output-file: wrappers.html
# title: Wrappers
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(hello)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L8){target="_blank" style="float:right; font-size:smaller"}
#
# ### hello
#
# >      hello ()

# %%
hello()
# Out:
#     Welcome :)
#
#     You can find additional documentation here: https://k111git.github.io/ab-test-toolkit/

# %%
#| echo: false
#| output: asis
show_doc(simulate_evolution_binary)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L31){target="_blank" style="float:right; font-size:smaller"}
#
# ### simulate_evolution_binary
#
# >      simulate_evolution_binary (N=10000, cr0=0.1, cr1=0.11,
# >                                 snapshot_sizes=array([ 1000,  2000,  3000,
# >                                 4000,  5000,  6000,  7000,  8000,  9000,
# >                                 10000]))
#
# Simulates the evolution of a binary experiment.

# %%
#| echo: false
#| output: asis
show_doc(realizations_of_evolution_binary)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L66){target="_blank" style="float:right; font-size:smaller"}
#
# ### realizations_of_evolution_binary
#
# >      realizations_of_evolution_binary (N_realizations=50, N=10000, cr0=0.1,
# >                                        cr1=0.11, snapshot_sizes=array([ 1000,
# >                                        2000,  3000,  4000,  5000,  6000,
# >                                        7000,  8000,  9000,        10000]))

# %%
#| echo: false
#| output: asis
show_doc(plot_realization)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L99){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_realization
#
# >      plot_realization (plot_df)

# %%
#| echo: false
#| output: asis
show_doc(plot_snapshots_distribution)
# Out:
# ---
#
# [source](https://github.com/k111git/ab-test-toolkit/blob/main/ab_test_toolkit/wrappers.py#L174){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_snapshots_distribution
#
# >      plot_snapshots_distribution (snapshots, vline_x=None)
